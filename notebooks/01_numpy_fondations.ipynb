# %%
import numpy as np

# %%
url_lengths = np.array([24, 34, 19, 2, 40])
print()
url_lengths.shape
# Out:
# (5,)

# %%
url_lengths.shape
# Out:
# (5,)

# %%
url_lengths
# Out:
# array([24, 34, 19,  2, 40])

# %%
url_lengths = np.array([24, 34, 19, 2, 40])
print()

# %%
url_lengths * 2
# Out:
# array([48, 68, 38,  4, 80])

# %%
url_lengths - 3
# Out:
# array([21, 31, 16, -1, 37])

# %%
url_lengths % 3
# Out:
# array([0, 1, 1, 2, 1])

# %%
url_lengths.dtype
# Out:
# dtype('int64')

# %%
url_lengths = np.array([24, 34, 19, 2, 40], dtype=float)

# %%
url_lengths % 3
# Out:
# array([0., 1., 1., 2., 1.])

# %%
url_lengths2 = np.array([24, 34, 19, 2, 40], dtype=float)

# %%
url_lengths2 % 3
# Out:
# array([0., 1., 1., 2., 1.])

# %%
url_lengths2.dtype
# Out:
# dtype('float64')

# %%
url_lengths2/3
# Out:
# array([ 8.        , 11.33333333,  6.33333333,  0.66666667, 13.33333333])

# %%
url_lengths[0]
# Out:
# np.float64(24.0)

# %%
url_lengths[2:3]
# Out:
# array([19.])

# %%
url_lengths[2:4]
# Out:
# array([19.,  2.])

# %%
url_lengths[1:]
# Out:
# array([34., 19.,  2., 40.])

# %%
url_lengths[:-1]
# Out:
# array([24., 34., 19.,  2.])

# %%
url_lengths[-1]
# Out:
# np.float64(40.0)

# %%
url_lengths[-2,-1]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 url_lengths[-2,-1]
#
# IndexError: too many indices for array: array is 1-dimensional, but 2 were indexed

# %%
url_lengths[-2:-1]
# Out:
# array([2.])

# %%
url_lengths[-2:]
# Out:
# array([ 2., 40.])

# %%
url_feature = np.array([[24, 34, 19, 2, 40], [24, 34, 19, 2, 40]])

# %%
url_feature.shape
# Out:
# (2, 5)

# %%
url_feature.dtype
# Out:
# dtype('int64')

# %%
url_feature[1,1]
# Out:
# np.int64(34)

# %%
url_feature[1,3]
# Out:
# np.int64(2)

# %%
url_feature[1,]
# Out:
# array([24, 34, 19,  2, 40])

# %%
url_feature[0]
# Out:
# array([24, 34, 19,  2, 40])

# %%
url_features = np.array([[4, 19, 4, 61, 59], [24, 34, 19, 2, 40]])

# %%
url_features[1,3]
# Out:
# np.int64(2)

# %%
url_features.shape
# Out:
# (2, 5)

# %%
url_features[0:]
# Out:
# array([[34, 19,  4, 61, 59],
#        [24, 34, 19,  2, 40]])

# %%
url_features[0:0]
# Out:
# array([], shape=(0, 5), dtype=int64)

# %%
url_features[0:1]
# Out:
# array([[34, 19,  4, 61, 59]])

# %%
url_features[:,0]
# Out:
# array([34, 24])

# %%
url_features.T
# Out:
# array([[34, 24],
#        [19, 34],
#        [ 4, 19],
#        [61,  2],
#        [59, 40]])

# %%
url_features.shape
# Out:
# (2, 5)

# %%
url_features.shape
# Out:
# (2, 5)

# %%
url_features.T.shape
# Out:
# (5, 2)

# %%
weights = np.array([[34, 19,  4],
       [24, 34, 19], [23, 139,  297], [21, 46,  98], [11, 18,  72]])

# %%
weights.shape
# Out:
# (5, 3)

# %%
url_features@weights
# Out:
# array([[ 3634,  5716, 11911],
#        [ 2551,  5065,  9461]])

# %%
(url_features[1,3] - url_lengths.min()) /(url_lengths.max()- url_lengths.min())
# Out:
# np.float64(0.0)

# %%
(url_lengths[1:3] - url_lengths.min()) /(url_lengths.max()- url_lengths.min())
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[49], line 1
# ----> 1 (url_lengths[1,3] - url_lengths.min()) /(url_lengths.max()- url_lengths.min())
#
# IndexError: too many indices for array: array is 1-dimensional, but 2 were indexed

# %%
(url_lengths - url_lengths.min()) /(url_lengths.max()- url_lengths.min())
# Out:
# array([0.57894737, 0.84210526, 0.44736842, 0.        , 1.        ])

# %%
(url_lengths -url_lengths.mean())/ url_lengths.std()
# Out:
# array([ 0.01520748,  0.77558131, -0.36497944, -1.65761495,  1.23180561])

# %%
dataset = np.array([[13, 45, 736], [35, 68, 6], [71, 111, 56]])

# %%
means = np.array([1, 5, 234])

# %%
dataset - means
# Out:
# array([[  12,   40,  502],
#        [  34,   63, -228],
#        [  70,  106, -178]])
